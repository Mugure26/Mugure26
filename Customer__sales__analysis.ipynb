# %% [markdown]
# <a href="https://colab.research.google.com/github/Mugure26/Mugure26/blob/main/Customer__sales__analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("All libraries loaded successfully!")
# Out:
# All libraries loaded successfully!

# %%
import pandas as pd

data = {
    "Date": [
        "2025-01-05", "2025-01-12", "2025-02-03", "2025-02-15",
        "2025-03-02", "2025-03-18", "2025-04-07", "2025-04-21",
        "2025-05-04", "2025-05-19", "2025-06-08", "2025-06-25",
        "2025-07-10", "2025-07-28", "2025-08-05", "2025-08-20",
        "2025-09-03", "2025-09-17", "2025-10-06", "2025-10-22"
    ],
    "Product": [
        "Laptop", "Mouse", "Keyboard", "Laptop",
        "Monitor", "Mouse", "Keyboard", "Laptop",
        "Monitor", "Headphones", "Laptop", "Mouse",
        "Keyboard", "Monitor", "Headphones", "Laptop",
        "Mouse", "Keyboard", "Laptop", "Monitor"
    ],
    "Category": [
        "Electronics", "Accessories", "Accessories", "Electronics",
        "Electronics", "Accessories", "Accessories", "Electronics",
        "Electronics", "Accessories", "Electronics", "Accessories",
        "Accessories", "Electronics", "Accessories", "Electronics",
        "Accessories", "Accessories", "Electronics", "Electronics"
    ],
    "Region": [
        "Nairobi", "Mombasa", "Nairobi", "Kisumu",
        "Nakuru", "Nairobi", "Mombasa", "Kisumu",
        "Nairobi", "Nakuru", "Mombasa", "Nairobi",
        "Kisumu", "Nakuru", "Nairobi", "Mombasa",
        "Kisumu", "Nairobi", "Nakuru", "Mombasa"
    ],
    "Quantity": [
        2, 10, 5, 3, 4, 15, 8, 2,
        5, 7, 3, 12, 6, 4, 10, 2,
        20, 9, 3, 6
    ],
    "Unit_Price": [
        85000, 1500, 3500, 85000, 25000, 1500, 3500, 85000,
        25000, 5000, 85000, 1500, 3500, 25000, 5000, 85000,
        1500, 3500, 85000, 25000
    ]
}

df = pd.DataFrame(data)

df["Date"] = pd.to_datetime(df["Date"])
df["Revenue"] = df["Quantity"] * df["Unit_Price"]

df.head()
# Out:
#         Date   Product     Category   Region  Quantity  Unit_Price  Revenue
# 0 2025-01-05    Laptop  Electronics  Nairobi         2       85000   170000
# 1 2025-01-12     Mouse  Accessories  Mombasa        10        1500    15000
# 2 2025-02-03  Keyboard  Accessories  Nairobi         5        3500    17500
# 3 2025-02-15    Laptop  Electronics   Kisumu         3       85000   255000
# 4 2025-03-02   Monitor  Electronics   Nakuru         4       25000   100000

# %%
df = pd.DataFrame(data)

# %%
print(df.head())
# Out:
#          Date   Product     Category   Region  Quantity  Unit_Price
# 0  2025-01-05    Laptop  Electronics  Nairobi         2       85000
# 1  2025-01-12     Mouse  Accessories  Mombasa        10        1500
# 2  2025-02-03  Keyboard  Accessories  Nairobi         5        3500
# 3  2025-02-15    Laptop  Electronics   Kisumu         3       85000
# 4  2025-03-02   Monitor  Electronics   Nakuru         4       25000

# %%
df.to_csv("sales_data.csv", index=False)
print("sales_data.csv created successfully!")
# Out:
# sales_data.csv created successfully!

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df["Revenue"] = df["Quantity"] * df["Unit_Price"]

# %%
print("Number of rows and columns:")
print(df.shape)

print("\nColumn names:")
print(df.columns.tolist())

print("\nDataset information:")
df.info()
# Out:
# Number of rows and columns:
# (20, 7)
#
# Column names:
# ['Date', 'Product', 'Category', 'Region', 'Quantity', 'Unit_Price', 'Revenue']
#
# Dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        20 non-null     datetime64[ns]
#  1   Product     20 non-null     object
#  2   Category    20 non-null     object
#  3   Region      20 non-null     object
#  4   Quantity    20 non-null     int64
#  5   Unit_Price  20 non-null     int64
#  6   Revenue     20 non-null     int64
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 1.2+ KB

# %%
df.describe()
# Out:
#                       Date   Quantity    Unit_Price        Revenue
# count                   20  20.000000     20.000000      20.000000
# mean   2025-05-28 12:00:00   6.800000  32000.000000  100925.000000
# min    2025-01-05 00:00:00   2.000000   1500.000000   15000.000000
# 25%    2025-03-14 00:00:00   3.000000   3500.000000   26625.000000
# 50%    2025-05-29 00:00:00   5.500000  15000.000000   75000.000000
# 75%    2025-08-08 18:00:00   9.250000  85000.000000  170000.000000
# max    2025-10-22 00:00:00  20.000000  85000.000000  255000.000000
# std                    NaN   4.763899  36618.948216   87173.945136

# %% [markdown]
# visualization

# %%
product_revenue = df.groupby("Product")["Revenue"].sum().sort_values(ascending=False)

print(product_revenue)
# Out:
# Product
# Laptop        1275000
# Monitor        475000
# Keyboard        98000
# Mouse           85500
# Headphones      85000
# Name: Revenue, dtype: int64

# %%
plt.figure(figsize=(10, 6))

product_revenue.plot(kind="bar")

plt.title("Revenue by Product")
plt.xlabel("Product")
plt.ylabel("Revenue (KSh)")
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
print(product_revenue)
# Out:
# Product
# Laptop        1275000
# Monitor        475000
# Keyboard        98000
# Mouse           85500
# Headphones      85000
# Name: Revenue, dtype: int64

# %% [markdown]
# analysis of quantity sold

# %%
product_quantity = df.groupby("Product")["Quantity"].sum().sort_values(ascending=False)

print(product_quantity)
# Out:
# Product
# Mouse         57
# Keyboard      28
# Monitor       19
# Headphones    17
# Laptop        15
# Name: Quantity, dtype: int64

# %%
plt.figure(figsize=(10, 6))

product_quantity.plot(kind="bar")

plt.title("Quantity Sold by Product")
plt.xlabel("Product")
plt.ylabel("Quantity Sold")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ANAYLSIS BY REGION

# %%
region_revenue = df.groupby("Region")["Revenue"].sum().sort_values(ascending=True)

print(region_revenue)
# Out:
# Region
# Nairobi    434500
# Kisumu     476000
# Nakuru     490000
# Mombasa    618000
# Name: Revenue, dtype: int64

# %%
plt.figure(figsize=(8, 5))

region_revenue.plot(kind="bar")

plt.title("Revenue by Region")
plt.xlabel("Region")
plt.ylabel("Revenue (KSh)")
plt.xticks(rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# sales over time

# %%
df["Month"] = df["Date"].dt.to_period("M").astype(str)

monthly_revenue = df.groupby("Month")["Revenue"].sum()

print(monthly_revenue)
# Out:
# Month
# 2025-01    185000
# 2025-02    272500
# 2025-03    122500
# 2025-04    198000
# 2025-05    160000
# 2025-06    273000
# 2025-07    121000
# 2025-08    220000
# 2025-09     61500
# 2025-10    405000
# Name: Revenue, dtype: int64

# %%
plt.figure(figsize=(12, 6))

monthly_revenue.plot(kind="line", marker="o")

plt.title("Monthly Revenue Trend")
plt.xlabel("Month")
plt.ylabel("Revenue (KSh)")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
print(monthly_revenue)
# Out:
# Month
# 2025-01    185000
# 2025-02    272500
# 2025-03    122500
# 2025-04    198000
# 2025-05    160000
# 2025-06    273000
# 2025-07    121000
# 2025-08    220000
# 2025-09     61500
# 2025-10    405000
# Name: Revenue, dtype: int64

# %%
df["Month"] = df["Date"].dt.month

monthly_revenue = df.groupby("Month")["Revenue"].sum()

# Add missing months
monthly_revenue = monthly_revenue.reindex(range(1, 13), fill_value=0)

# Give months proper names
month_names = [
    "January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"
]

monthly_revenue.index = month_names

print(monthly_revenue)
# Out:
# January      185000
# February     272500
# March        122500
# April        198000
# May          160000
# June         273000
# July         121000
# August       220000
# September     61500
# October      405000
# November          0
# December          0
# Name: Revenue, dtype: int64

# %%
plt.figure(figsize=(12, 6))

monthly_revenue.plot(kind="line", marker="o")

plt.title("Monthly Revenue Trend")
plt.xlabel("Month")
plt.ylabel("Revenue (KSh)")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
print("===== DATA QUALITY CHECK =====")

print("\nMissing values:")
print(df.isnull().sum())

print("\nDuplicate rows:")
print(df.duplicated().sum())
# Out:
# ===== DATA QUALITY CHECK =====
#
# Missing values:
# Date          0
# Product       0
# Category      0
# Region        0
# Quantity      0
# Unit_Price    0
# Revenue       0
# Month         0
# dtype: int64
#
# Duplicate rows:
# 0

# %% [markdown]
# category analysis

# %%
category_revenue = df.groupby("Category")["Revenue"].sum().sort_values(ascending=False)

print(category_revenue)
# Out:
# Category
# Electronics    1750000
# Accessories     268500
# Name: Revenue, dtype: int64

# %%
plt.figure(figsize=(8, 5))

category_revenue.plot(kind="bar")

plt.title("Revenue by Product Category")
plt.xlabel("Category")
plt.ylabel("Revenue (KSh)")
plt.xticks(rotation=0)

plt.tight_layout()
plt.show()

# %%
category_quantity = df.groupby("Category")["Quantity"].sum().sort_values(ascending=False)

print(category_quantity)
# Out:
# Category
# Accessories    102
# Electronics     34
# Name: Quantity, dtype: int64

# %%
region_product = df.pivot_table(
    index="Region",
    columns="Product",
    values="Revenue",
    aggfunc="sum",
    fill_value=0
)

print(region_product)
# Out:
# Product  Headphones  Keyboard  Laptop  Monitor  Mouse
# Region
# Kisumu            0     21000  425000        0  30000
# Mombasa           0     28000  425000   150000  15000
# Nairobi       50000     49000  170000   125000  40500
# Nakuru        35000         0  255000   200000      0

# %%
plt.figure(figsize=(12, 6))

sns.heatmap(region_product, annot=True, fmt=".0f")

plt.title("Revenue by Region and Product")
plt.xlabel("Product")
plt.ylabel("Region")

plt.tight_layout()
plt.show()

# %% [markdown]
# visualization by region

# %%
region_product.plot(
    kind="bar",
    figsize=(12, 6)
)

plt.title("Revenue by Region and Product")
plt.xlabel("Region")
plt.ylabel("Revenue (KSh)")
plt.xticks(rotation=0)
plt.legend(title="Product")

plt.tight_layout()
plt.show()

# %% [markdown]
# correlation analysis:investigate whether Quantity, Unit Price, and Revenue are related.

# %%
correlation = df[["Quantity", "Unit_Price", "Revenue"]].corr()

print(correlation)
# Out:
#             Quantity  Unit_Price   Revenue
# Quantity    1.000000   -0.704021 -0.673762
# Unit_Price -0.704021    1.000000  0.932436
# Revenue    -0.673762    0.932436  1.000000

# %%
plt.figure(figsize=(8, 6))

sns.heatmap(
    correlation,
    annot=True,
    fmt=".2f"
)

plt.title("Correlation Between Sales Variables")

plt.tight_layout()
plt.show()

# %%
total_revenue = df["Revenue"].sum()
total_units = df["Quantity"].sum()
total_transactions = len(df)
average_transaction = df["Revenue"].mean()

print("===== SALES KPI SUMMARY =====")
print(f"Total Revenue: KSh {total_revenue:,.0f}")
print(f"Total Units Sold: {total_units:,}")
print(f"Total Transactions: {total_transactions:,}")
print(f"Average Transaction Value: KSh {average_transaction:,.0f}")
# Out:
# ===== SALES KPI SUMMARY =====
# Total Revenue: KSh 2,018,500
# Total Units Sold: 136
# Total Transactions: 20
# Average Transaction Value: KSh 100,925

# %%
fig, axes = plt.subplots(1, 4, figsize=(16, 4))

kpis = [
    ("Total Revenue", f"KSh {total_revenue:,.0f}"),
    ("Units Sold", f"{total_units:,}"),
    ("Transactions", f"{total_transactions:,}"),
    ("Average Sale", f"KSh {average_transaction:,.0f}")
]

for ax, (title, value) in zip(axes, kpis):
    ax.text(
        0.5, 0.5, value,
        ha="center",
        va="center",
        fontsize=20,
        fontweight="bold"
    )
    ax.set_title(title)
    ax.axis("off")

plt.suptitle("Customer Sales Analysis — KPI Dashboard", fontsize=18)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a 2x2 dashboard
fig, axes = plt.subplots(2, 2, figsize=(16, 10))

# 1. Revenue by Product
product_revenue = df.groupby("Product")["Revenue"].sum().sort_values()

axes[0, 0].barh(product_revenue.index, product_revenue.values)
axes[0, 0].set_title("Revenue by Product")
axes[0, 0].set_xlabel("Revenue (KSh)")

# 2. Revenue by Region
region_revenue = df.groupby("Region")["Revenue"].sum().sort_values()

axes[0, 1].bar(region_revenue.index, region_revenue.values)
axes[0, 1].set_title("Revenue by Region")
axes[0, 1].set_ylabel("Revenue (KSh)")

# 3. Monthly Revenue
monthly_revenue = df.groupby("Month")["Revenue"].sum()

axes[1, 0].plot(monthly_revenue.index.astype(str),
                monthly_revenue.values,
                marker="o")

axes[1, 0].set_title("Monthly Revenue Trend")
axes[1, 0].set_xlabel("Month")
axes[1, 0].set_ylabel("Revenue (KSh)")
axes[1, 0].tick_params(axis="x", rotation=45)

# 4. Revenue by Category
category_revenue = df.groupby("Category")["Revenue"].sum()

axes[1, 1].bar(category_revenue.index, category_revenue.values)
axes[1, 1].set_title("Revenue by Category")
axes[1, 1].set_ylabel("Revenue (KSh)")

plt.suptitle(
    "Customer Sales Analysis — Business Insights Dashboard",
    fontsize=18
)

plt.tight_layout()
plt.show()

# %%
df.to_csv("sales_data.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2106/685861465.py in <cell line: 0>()
# ----> 1 df.to_csv("sales_data.csv", index=False)
#
# NameError: name 'df' is not defined

# %%
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2106/3810112079.py in <cell line: 0>()
# ----> 1 print(df.head())
#
# NameError: name 'df' is not defined

# %%
df.to_csv("sales_data.csv", index=False)
print("CSV created successfully!")
# Out:
# CSV created successfully!

# %% [markdown]
# sql file

# %%
# %%writefile sales_analysis.sql
#
# -- Customer Sales Analysis
# -- SQL Business Analysis
#
# -- 1. Total Revenue
# SELECT SUM(Revenue) AS Total_Revenue
# FROM sales_data;
#
# -- 2. Total Units Sold
# SELECT SUM(Quantity) AS Total_Units_Sold
# FROM sales_data;
#
# -- 3. Revenue by Product
# SELECT
#     Product,
#     SUM(Revenue) AS Total_Revenue
# FROM sales_data
# GROUP BY Product
# ORDER BY Total_Revenue DESC;
#
# -- 4. Revenue by Region
# SELECT
#     Region,
#     SUM(Revenue) AS Total_Revenue
# FROM sales_data
# GROUP BY Region
# ORDER BY Total_Revenue DESC;
#
# -- 5. Revenue by Category
# SELECT
#     Category,
#     SUM(Revenue) AS Total_Revenue
# FROM sales_data
# GROUP BY Category
# ORDER BY Total_Revenue DESC;
# Out:
# Overwriting sales_analysis.sql

# %%
import sqlite3
import pandas as pd

# Connect to a database
conn = sqlite3.connect("sales_analysis.db")

print("Database connected successfully!")
# Out:
# Database connected successfully!

# %%
sales_df = pd.read_csv("sales_data.csv")

sales_df.to_sql(
    "sales_data",
    conn,
    if_exists="replace",
    index=False
)

print("Sales data loaded into SQL successfully!")
# Out:
# Sales data loaded into SQL successfully!

# %%
query = """
SELECT SUM(Revenue) AS Total_Revenue
FROM sales_data;
"""

result = pd.read_sql_query(query, conn)

result
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: no such column: Revenue
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipykernel_2106/2898755260.py in <cell line: 0>()
#       4 """
#       5
# ----> 6 result = pd.read_sql_query(query, conn)
#       7
#       8 result
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     524
#     525     with pandasSQL_builder(con) as pandas_sql:
# --> 526         return pandas_sql.read_query(
# ...

# %%
print(sales_df.columns.tolist())
# Out:
# ['Date', 'Product', 'Category', 'Region', 'Quantity', 'Unit_Price']

# %%
sales_df.head()
# Out:
#          Date   Product     Category   Region  Quantity  Unit_Price
# 0  2025-01-05    Laptop  Electronics  Nairobi         2       85000
# 1  2025-01-12     Mouse  Accessories  Mombasa        10        1500
# 2  2025-02-03  Keyboard  Accessories  Nairobi         5        3500
# 3  2025-02-15    Laptop  Electronics   Kisumu         3       85000
# 4  2025-03-02   Monitor  Electronics   Nakuru         4       25000

# %%
sales_df["Revenue"] = sales_df["Quantity"] * sales_df["Unit_Price"]

sales_df.to_csv("sales_data.csv", index=False)

print("Revenue column added and CSV updated!")
# Out:
# Revenue column added and CSV updated!

# %%
sales_df.to_sql(
    "sales_data",
    conn,
    if_exists="replace",
    index=False
)

print("SQL table updated!")
# Out:
# SQL table updated!

# %%
query = """
SELECT SUM(Revenue) AS Total_Revenue
FROM sales_data;
"""

result = pd.read_sql_query(query, conn)

result
# Out:
#    Total_Revenue
# 0        2018500

# %%
print(sales_df.columns.tolist())
# Out:
# ['Date', 'Product', 'Category', 'Region', 'Quantity', 'Unit_Price', 'Revenue']

# %%
sales_df.to_sql(
    "sales_data",
    conn,
    if_exists="replace",
    index=False
)

print("SQL table refreshed successfully!")
# Out:
# SQL table refreshed successfully!

# %%
pd.read_sql_query(
    "PRAGMA table_info(sales_data);",
    conn
)
# Out:
#    cid        name     type  notnull dflt_value  pk
# 0    0        Date     TEXT        0       None   0
# 1    1     Product     TEXT        0       None   0
# 2    2    Category     TEXT        0       None   0
# 3    3      Region     TEXT        0       None   0
# 4    4    Quantity  INTEGER        0       None   0
# 5    5  Unit_Price  INTEGER        0       None   0
# 6    6     Revenue  INTEGER        0       None   0

# %%
query = """
SELECT SUM(Revenue) AS Total_Revenue
FROM sales_data;
"""

result = pd.read_sql_query(query, conn)

result
# Out:
#    Total_Revenue
# 0        2018500

# %%
query = """
SELECT
    Product,
    SUM(Revenue) AS Total_Revenue
FROM sales_data
GROUP BY Product
ORDER BY Total_Revenue DESC;
"""

pd.read_sql_query(query, conn)
# Out:
#       Product  Total_Revenue
# 0      Laptop        1275000
# 1     Monitor         475000
# 2    Keyboard          98000
# 3       Mouse          85500
# 4  Headphones          85000

# %%
query = """
SELECT SUM(Quantity) AS Total_Units_Sold
FROM sales_data;
"""

pd.read_sql_query(query, conn)
# Out:
#    Total_Units_Sold
# 0               136

# %%
query = """
SELECT
    Product,
    SUM(Revenue) AS Total_Revenue
FROM sales_data
GROUP BY Product
ORDER BY Total_Revenue DESC;
"""

pd.read_sql_query(query, conn)
# Out:
#       Product  Total_Revenue
# 0      Laptop        1275000
# 1     Monitor         475000
# 2    Keyboard          98000
# 3       Mouse          85500
# 4  Headphones          85000

# %%
query = """
SELECT
    Region,
    SUM(Revenue) AS Total_Revenue
FROM sales_data
GROUP BY Region
ORDER BY Total_Revenue DESC;
"""

pd.read_sql_query(query, conn)
# Out:
#     Region  Total_Revenue
# 0  Mombasa         618000
# 1   Nakuru         490000
# 2   Kisumu         476000
# 3  Nairobi         434500

# %%
query = """
SELECT
    Category,
    SUM(Revenue) AS Total_Revenue
FROM sales_data
GROUP BY Category
ORDER BY Total_Revenue DESC;
"""

pd.read_sql_query(query, conn)
# Out:
#       Category  Total_Revenue
# 0  Electronics        1750000
# 1  Accessories         268500

# %%
query = """
SELECT
    Month,
    SUM(Revenue) AS Monthly_Revenue
FROM sales_data
GROUP BY Month
ORDER BY Month;
"""

pd.read_sql_query(query, conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: no such column: Month
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipykernel_2106/2243272412.py in <cell line: 0>()
#       8 """
#       9
# ---> 10 pd.read_sql_query(query, conn)
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     524
#     525     with pandasSQL_builder(con) as pandas_sql:
# --> 526         return pandas_sql.read_query(
#     527             sql,
# ...

# %%
sales_df["Date"] = pd.to_datetime(sales_df["Date"])

sales_df["Month"] = sales_df["Date"].dt.to_period("M").astype(str)

print(sales_df.columns.tolist())
# Out:
# ['Date', 'Product', 'Category', 'Region', 'Quantity', 'Unit_Price', 'Revenue', 'Month']

# %%
sales_df.to_csv("sales_data.csv", index=False)

print("CSV updated successfully!")
# Out:
# CSV updated successfully!

# %%
sales_df.to_sql(
    "sales_data",
    conn,
    if_exists="replace",
    index=False
)

print("SQL table updated successfully!")
# Out:
# SQL table updated successfully!

# %%
query = """
SELECT
    Month,
    SUM(Revenue) AS Monthly_Revenue
FROM sales_data
GROUP BY Month
ORDER BY Month;
"""

pd.read_sql_query(query, conn)
# Out:
#      Month  Monthly_Revenue
# 0  2025-01           185000
# 1  2025-02           272500
# 2  2025-03           122500
# 3  2025-04           198000
# 4  2025-05           160000
# 5  2025-06           273000
# 6  2025-07           121000
# 7  2025-08           220000
# 8  2025-09            61500
# 9  2025-10           405000

# %%
# %%writefile /content/sales_analysis.sql
#
# -- ==========================================
# -- CUSTOMER SALES ANALYSIS
# -- SQL BUSINESS ANALYSIS
# -- ==========================================
#
# -- 1. Total Revenue
# SELECT
#     SUM(Revenue) AS Total_Revenue
# FROM sales_data;
#
#
# -- 2. Total Units Sold
# SELECT
#     SUM(Quantity) AS Total_Units_Sold
# FROM sales_data;
#
#
# -- 3. Revenue by Product
# SELECT
#     Product,
#     SUM(Revenue) AS Total_Revenue
# FROM sales_data
# GROUP BY Product
# ORDER BY Total_Revenue DESC;
#
#
# -- 4. Revenue by Region
# SELECT
#     Region,
#     SUM(Revenue) AS Total_Revenue
# FROM sales_data
# GROUP BY Region
# ORDER BY Total_Revenue DESC;
#
#
# -- 5. Revenue by Category
# SELECT
#     Category,
#     SUM(Revenue) AS Total_Revenue
# FROM sales_data
# GROUP BY Category
# ORDER BY Total_Revenue DESC;
#
#
# -- 6. Monthly Revenue
# SELECT
#     Month,
#     SUM(Revenue) AS Monthly_Revenue
# FROM sales_data
# GROUP BY Month
# ORDER BY Month;
# Out:
# Overwriting /content/sales_analysis.sql

# %%
import pandas as pd
import numpy as np

# Make a copy so the original data remains safe
portfolio_df = sales_df.copy()

# Create customer IDs
customer_ids = [
    "C001", "C002", "C003", "C004", "C005",
    "C006", "C007", "C008", "C009", "C010"
]

# Assign customers to transactions
portfolio_df["Customer_ID"] = [
    "C001", "C002", "C003", "C001", "C004",
    "C005", "C002", "C006", "C003", "C007",
    "C001", "C008", "C005", "C009", "C010",
    "C006", "C008", "C002", "C004", "C009"
]

portfolio_df.head()
# Out:
#         Date   Product     Category   Region  Quantity  Unit_Price  Revenue  \
# 0 2025-01-05    Laptop  Electronics  Nairobi         2       85000   170000
# 1 2025-01-12     Mouse  Accessories  Mombasa        10        1500    15000
# 2 2025-02-03  Keyboard  Accessories  Nairobi         5        3500    17500
# 3 2025-02-15    Laptop  Electronics   Kisumu         3       85000   255000
# 4 2025-03-02   Monitor  Electronics   Nakuru         4       25000   100000
#
#      Month Customer_ID
# 0  2025-01        C001
# 1  2025-01        C002
# 2  2025-02        C003
# 3  2025-02        C001
# 4  2025-03        C004

# %%
portfolio_df.shape
# Out:
# (20, 9)

# %%
portfolio_df.columns.tolist()
# Out:
# ['Date',
#  'Product',
#  'Category',
#  'Region',
#  'Quantity',
#  'Unit_Price',
#  'Revenue',
#  'Month',
#  'Customer_ID']

# %%
portfolio_df.to_csv(
    "customer_sales_portfolio.csv",
    index=False
)

print("Portfolio dataset created successfully!")
# Out:
# Portfolio dataset created successfully!

# %% [markdown]
# revenue each customer spend

# %%
customer_revenue = (
    portfolio_df
    .groupby("Customer_ID")["Revenue"]
    .sum()
    .sort_values(ascending=False)
)

customer_revenue
# Out:
# Customer_ID
# C001    680000
# C004    355000
# C006    340000
# C009    250000
# C003    142500
# C002     74500
# C010     50000
# C008     48000
# C005     43500
# C007     35000
# Name: Revenue, dtype: int64

# %% [markdown]
# customer purchase frequency

# %%
customer_transactions = (
    portfolio_df
    .groupby("Customer_ID")
    .size()
    .sort_values(ascending=False)
)

customer_transactions
# Out:
# Customer_ID
# C001    3
# C002    3
# C003    2
# C004    2
# C005    2
# C006    2
# C008    2
# C009    2
# C007    1
# C010    1
# dtype: int64

# %% [markdown]
# customer summary

# %%
customer_summary = (
    portfolio_df
    .groupby("Customer_ID")
    .agg(
        Total_Revenue=("Revenue", "sum"),
        Total_Units=("Quantity", "sum"),
        Transactions=("Revenue", "count"),
        Average_Transaction=("Revenue", "mean")
    )
    .sort_values("Total_Revenue", ascending=False)
)

customer_summary
# Out:
#              Total_Revenue  Total_Units  Transactions  Average_Transaction
# Customer_ID
# C001                680000            8             3        226666.666667
# C004                355000            7             2        177500.000000
# C006                340000            4             2        170000.000000
# C009                250000           10             2        125000.000000
# C003                142500           10             2         71250.000000
# C002                 74500           27             3         24833.333333
# C010                 50000           10             1         50000.000000
# C008                 48000           32             2         24000.000000
# C005                 43500           21             2         21750.000000
# C007                 35000            7             1         35000.000000

# %% [markdown]
# customer segmentation

# %%
def segment_customer(revenue):
    if revenue >= 250000:
        return "High Value"
    elif revenue >= 100000:
        return "Medium Value"
    else:
        return "Low Value"


customer_summary["Segment"] = customer_summary["Total_Revenue"].apply(
    segment_customer
)

customer_summary
# Out:
#              Total_Revenue  Total_Units  Transactions  Average_Transaction  \
# Customer_ID
# C001                680000            8             3        226666.666667
# C004                355000            7             2        177500.000000
# C006                340000            4             2        170000.000000
# C009                250000           10             2        125000.000000
# C003                142500           10             2         71250.000000
# C002                 74500           27             3         24833.333333
# C010                 50000           10             1         50000.000000
# C008                 48000           32             2         24000.000000
# C005                 43500           21             2         21750.000000
# C007                 35000            7             1         35000.000000
#
#                   Segment
# Customer_ID
# C001           High Value
# C004           High Value
# C006           High Value
# ...

# %%
segment_counts = customer_summary["Segment"].value_counts()

segment_counts
# Out:
# Segment
# Low Value       5
# High Value      4
# Medium Value    1
# Name: count, dtype: int64

# %% [markdown]
# revenue by segment

# %%
segment_revenue = (
    customer_summary
    .groupby("Segment")["Total_Revenue"]
    .sum()
    .sort_values(ascending=False)
)

segment_revenue
# Out:
# Segment
# High Value      1625000
# Low Value        251000
# Medium Value     142500
# Name: Total_Revenue, dtype: int64

# %% [markdown]
# visual segment

# %%
import matplotlib.pyplot as plt

segment_counts.plot(
    kind="bar",
    figsize=(8, 5)
)

plt.title("Customer Segmentation")
plt.xlabel("Customer Segment")
plt.ylabel("Number of Customers")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

segment_revenue = (
    customer_summary
    .groupby("Segment")["Total_Revenue"]
    .sum()
    .sort_values(ascending=False)
)

plt.figure(figsize=(8, 5))

plt.bar(
    segment_revenue.index,
    segment_revenue.values
)

plt.title("Revenue Contribution by Customer Segment")
plt.xlabel("Customer Segment")
plt.ylabel("Revenue (KSh)")

plt.tight_layout()
plt.show()

# %%
top_customers = customer_summary.head(5)

top_customers
# Out:
#              Total_Revenue  Total_Units  Transactions  Average_Transaction  \
# Customer_ID
# C001                680000            8             3        226666.666667
# C004                355000            7             2        177500.000000
# C006                340000            4             2        170000.000000
# C009                250000           10             2        125000.000000
# C003                142500           10             2         71250.000000
#
#                   Segment
# Customer_ID
# C001           High Value
# C004           High Value
# C006           High Value
# C009           High Value
# C003         Medium Value

# %%
plt.figure(figsize=(8, 5))

plt.barh(
    top_customers.index,
    top_customers["Total_Revenue"]
)

plt.title("Top 5 Customers by Revenue")
plt.xlabel("Revenue (KSh)")
plt.ylabel("Customer ID")

plt.tight_layout()
plt.show()

# %%
total_customers = customer_summary.shape[0]

average_customer_revenue = customer_summary["Total_Revenue"].mean()

repeat_customers = (
    customer_summary["Transactions"] > 1
).sum()

print("===== CUSTOMER KPI SUMMARY =====")
print(f"Total Customers: {total_customers}")
print(f"Average Customer Revenue: KSh {average_customer_revenue:,.0f}")
print(f"Repeat Customers: {repeat_customers}")
# Out:
# ===== CUSTOMER KPI SUMMARY =====
# Total Customers: 10
# Average Customer Revenue: KSh 201,850
# Repeat Customers: 8

# %%
customer_summary.to_csv(
    "customer_analysis.csv"
)

print("Customer analysis saved successfully!")
# Out:
# Customer analysis saved successfully!

# %%
import matplotlib.pyplot as plt

# -----------------------------
# Prepare dashboard data
# -----------------------------

product_revenue = (
    portfolio_df.groupby("Product")["Revenue"]
    .sum()
    .sort_values(ascending=False)
)

region_revenue = (
    portfolio_df.groupby("Region")["Revenue"]
    .sum()
    .sort_values(ascending=False)
)

monthly_revenue = (
    portfolio_df.groupby("Month")["Revenue"]
    .sum()
)

segment_revenue = (
    customer_summary.groupby("Segment")["Total_Revenue"]
    .sum()
    .sort_values(ascending=False)
)

# -----------------------------
# Create dashboard
# -----------------------------

fig, axes = plt.subplots(2, 2, figsize=(16, 10))

# 1. Product Revenue
axes[0, 0].bar(
    product_revenue.index,
    product_revenue.values
)

axes[0, 0].set_title("Revenue by Product")
axes[0, 0].set_xlabel("Product")
axes[0, 0].set_ylabel("Revenue (KSh)")
axes[0, 0].tick_params(axis="x", rotation=30)


# 2. Regional Revenue
axes[0, 1].bar(
    region_revenue.index,
    region_revenue.values
)

axes[0, 1].set_title("Revenue by Region")
axes[0, 1].set_xlabel("Region")
axes[0, 1].set_ylabel("Revenue (KSh)")


# 3. Monthly Revenue
axes[1, 0].plot(
    monthly_revenue.index,
    monthly_revenue.values,
    marker="o"
)

axes[1, 0].set_title("Monthly Revenue Trend")
axes[1, 0].set_xlabel("Month")
axes[1, 0].set_ylabel("Revenue (KSh)")
axes[1, 0].tick_params(axis="x", rotation=45)


# 4. Customer Segment Revenue
axes[1, 1].bar(
    segment_revenue.index,
    segment_revenue.values
)

axes[1, 1].set_title("Revenue by Customer Segment")
axes[1, 1].set_xlabel("Customer Segment")
axes[1, 1].set_ylabel("Revenue (KSh)")
axes[1, 1].tick_params(axis="x", rotation=20)


plt.suptitle(
    "Customer Sales Analysis — Final Business Dashboard",
    fontsize=18
)

plt.tight_layout()
plt.show()

# %%
plt.savefig(
    "final_sales_dashboard.png",
    dpi=300,
    bbox_inches="tight"
)

print("Final dashboard saved!")
# Out:
# Final dashboard saved!

# %%
# %%writefile /content/README.md
#
# # Customer Sales Analysis & Business Insights
#
# ## Project Overview
#
# This project analyzes customer sales data to identify revenue patterns,
# product performance, regional performance, monthly trends, and customer value.
#
# The project demonstrates how Python, SQL, statistics, and data visualization
# can be used to transform sales data into meaningful business insights.
#
# ---
#
# ## Business Problem
#
# A retail business wants to understand:
#
# - Which products generate the most revenue?
# - Which products sell the highest number of units?
# - Which regions perform best?
# - How does revenue change over time?
# - Which product categories generate the most revenue?
# - Who are the most valuable customers?
# - How can the business improve sales performance?
#
# ---
#
# ## Objectives
#
# The main objectives of this project are to:
#
# 1. Clean and prepare sales data.
# 2. Perform exploratory data analysis.
# 3. Calculate important sales KPIs.
# 4. Analyze product and regional performance.
# 5. Analyze monthly revenue trends.
# 6. Perform customer-level analysis.
# 7. Segment customers based on revenue.
# 8. Use SQL to perform business analysis.
# 9. Create visualizations and dashboards.
# 10. Provide data-driven business recommendations.
#
# ---
#
# ## Tools & Technologies
#
# - Python
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
# - SQL
# - SQLite
# - Google Colab
# - Data Visualization
# - Exploratory Data Analysis
#
# ---
#
# ## Key Performance Indicators
#
# | KPI | Result |
# |---|---:|
# | Total Revenue | KSh 2,018,500 |
# | Total Units Sold | 136 |
# | Total Transactions | 20 |
# | Average Transaction Value | KSh 100,925 |
#
# ---
#
# ## Key Findings
#
# ### Product Performance
#
# Laptops generated the highest revenue in the dataset, while mice
# recorded the highest number of units sold.
#
# This demonstrates that the product with the highest sales volume
# does not necessarily generate the highest revenue.
#
# ### Regional Performance
#
# Mombasa recorded the highest revenue among the regions analyzed.
#
# The business can investigate the factors contributing to this
# performance and determine whether successful strategies can be
# applied to other regions.
#
# ### Category Performance
#
# Electronics generated significantly more revenue than accessories,
# while accessories recorded higher sales volume.
#
# ### Monthly Performance
#
# Revenue varied considerably across the months in the dataset.
# October recorded the highest monthly revenue.
#
# ### Customer Analysis
#
# Customer-level analysis was performed to identify high-value,
# medium-value, and low-value customers.
#
# ---
#
# ## Customer Segmentation
#
# Customers were segmented according to their total revenue contribution.
#
# The segments include:
#
# - High Value
# - Medium Value
# - Low Value
#
# This segmentation can help a business develop targeted marketing
# and customer retention strategies.
#
# ---
#
# ## SQL Analysis
#
# SQL was used to calculate:
#
# - Total revenue
# - Total units sold
# - Revenue by product
# - Revenue by region
# - Revenue by category
# - Monthly revenue
#
# The SQL queries are available in:
#
# `sql/sales_analysis.sql`
#
# ---
#
# ## Business Recommendations
#
# ### 1. Focus on High-Value Products
#
# Maintain adequate inventory of high-revenue products such as laptops
# and use targeted marketing campaigns to maximize their contribution.
#
# ### 2. Use Product Bundling
#
# Combine high-value electronics with popular accessories such as mice
# and keyboards to increase transaction value.
#
# ### 3. Investigate Regional Performance
#
# Mombasa generated the highest revenue. The business should investigate
# the factors contributing to this performance.
#
# ### 4. Monitor Sales Trends
#
# Large monthly fluctuations should be investigated to identify possible
# seasonal patterns, promotions, stock issues, or changes in customer demand.
#
# ### 5. Use Customer Segmentation
#
# High-value customers should receive targeted retention strategies,
# while lower-value customers can be encouraged to increase their
# purchase frequency or transaction value.
#
# ---
#
# ## Project Structure
#
# ```text
# Customer-Sales-Analysis/
# │
# ├── data/
# │   └── sales_data.csv
# │
# ├── notebooks/
# │   └── customer_sales_analysis.ipynb
# │
# ├── sql/
# │   └── sales_analysis.sql
# │
# ├── visualizations/
# │   └── final_sales_dashboard.png
# │
# ├── customer_sales_analysis.py
# ├── customer_sales_portfolio.csv
# ├── customer_analysis.csv
# ├── README.md
# └── requirements.txt
# Out:
# Writing /content/README.md
